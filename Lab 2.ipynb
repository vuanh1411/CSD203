# %%
#Question1
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
class Stack:
    def __init__(self):
        self.head = None
    def isEmpty(self):
        return self.head is None
    def clear(self):
        self.head = None
    def push(self, x):
        new_node = Node(x)
        new_node.next = self.head
        self.head = new_node
    def pop(self):
        if self.isEmpty():
            raise EmptyStackException("Stack is empty")
        popped_node = self.head
        self.head = self.head.next
        return popped_node.data
    def top(self):
        if self.isEmpty():
            raise EmptyStackException("Stack is empty")
        return self.head.data
    def traverse(self):
        current_node = self.head
        while current_node is not None:
            print(current_node.data)
            current_node = current_node.next
def decimal_to_binary(n):
    stack = Stack()
    while n > 0:
        stack.push(n % 2)
        n //= 2
    binary_string = ""
    while not stack.isEmpty():
        binary_string += str(stack.pop())
    return binary_string
if __name__ == "__main__":
    n = int(input("Enter an integer in decimal system: "))
    binary_string = decimal_to_binary(n)
    print(f"Binary representation of {n} is: {binary_string}")
#Question2
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
class Queue:
    def __init__(self):
        self.head = None
        self.tail = None
    def is_empty(self):
        return self.head is None
    def clear(self):
        self.head = None
        self.tail = None
    def enqueue(self, x):
        new_node = Node(x)
        if self.is_empty():
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            self.tail = new_node
    def dequeue(self):
        if self.is_empty():
            raise Exception("Queue is empty")
        value = self.head.data
        self.head = self.head.next
        if self.head is None:
            self.tail = None
        return value
    def first(self):
        if self.is_empty():
            raise Exception("Queue is empty")
        return self.head.data
    def traverse(self):
        current_node = self.head
        while current_node is not None:
            print(current_node.data, end=" ")
            current_node = current_node.next
        print()
    def convert_to_binary(self, number):
        while number > 0:
            remainder = int(number % 2)
            self.enqueue(remainder)
            number //= 2
        binary_string = ""
        while not self.is_empty():
            binary_string += str(self.dequeue())
        return binary_string
if __name__ == "__main__":
    queue = Queue()
    queue.traverse()  
    print(queue.first())  
    queue.dequeue()
    queue.traverse() 
    queue.clear()
    queue
